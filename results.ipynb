# %%
# Do not edit. These are the only imports permitted.
import numpy as np
from abc import ABC, abstractmethod
from sklearn.tree import DecisionTreeClassifier   # for Task 4
from sklearn.base import clone                    # optional for Task 4
import matplotlib.pyplot as plt                   # for Task 5
from sklearn.metrics.pairwise import rbf_kernel   # for Task 6
from collections import Counter
import seaborn as sns
import pickle

# %%
with open ('./Outputs/BalancedEpsGreedy', 'rb') as fp:
    BalancedEpsGreedy = pickle.load(fp)

# %%
# H.append([arms[i], rewards[i], 1-gini(dist), pspscore]) 
np.shape(BalancedEpsGreedy[0][0])
# Out:
# (272531, 4)

# %%
sns.lineplot(BalancedEpsGreedy[0][0][:,2])
# Out:
# <AxesSubplot:>

# %%
plt.plot(BalancedEpsGreedy[0][0][:,2])
plt.plot(BalancedEpsGreedy[1][0][:,2])
plt.plot(BalancedEpsGreedy[2][0][:,2])

# %%
fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

axs[0].plot(np.cumsum(BalancedEpsGreedy[0][0][:,1]))
axs[0].plot(np.cumsum(BalancedEpsGreedy[1][0][:,1]))
axs[0].plot(np.cumsum(BalancedEpsGreedy[2][0][:,1]))
axs[0].set_title("Accuracy of Balanced Epsilon Greedy Algorithm")

axs[1].plot(BalancedEpsGreedy[0][0][:,2])
axs[1].plot(BalancedEpsGreedy[1][0][:,2])
axs[1].plot(BalancedEpsGreedy[2][0][:,2])
axs[1].set_title("Gini Index of Balanced Epsilon Greedy Algorithm")

axs[2].plot(BalancedEpsGreedy[0][0][:,3])
axs[2].plot(BalancedEpsGreedy[1][0][:,3])
axs[2].plot(BalancedEpsGreedy[2][0][:,3])
axs[2].set_title("PSP Score of Balanced Epsilon Greedy Algorithm")
# Out:
# Text(0.5, 1.0, 'PSP Score of Balanced Epsilon Greedy Algorithm')

# %%
with open ('./Outputs/BalancedUCB', 'rb') as fp:
    BalancedUCB = pickle.load(fp)
    fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

    axs[0].plot(np.cumsum(BalancedUCB[0][0][:,1]))
    axs[0].plot(np.cumsum(BalancedUCB[1][0][:,1]))
    axs[0].plot(np.cumsum(BalancedUCB[2][0][:,1]))
    axs[0].set_title("Accuracy of Balanced UCB Algorithm")

    axs[1].plot(BalancedUCB[0][0][:,2])
    axs[1].plot(BalancedUCB[1][0][:,2])
    axs[1].plot(BalancedUCB[2][0][:,2])
    axs[1].set_title("Gini Index of Balanced UCB Algorithm")

    axs[2].plot(BalancedUCB[0][0][:,3])
    axs[2].plot(BalancedUCB[1][0][:,3])
    axs[2].plot(BalancedUCB[2][0][:,3])
    axs[2].set_title("PSP Score of Balanced UCB Algorithm")

# %%
with open ('./Outputs/EpsGreedy', 'rb') as fp:
    EpsGreedy = pickle.load(fp)
    fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

    axs[0].plot(np.cumsum(EpsGreedy[0][0][:,1]))
    axs[0].plot(np.cumsum(EpsGreedy[1][0][:,1]))
    axs[0].plot(np.cumsum(EpsGreedy[2][0][:,1]))
    axs[0].set_title("Accuracy of Epsilon Greedy Algorithm")

    axs[1].plot(EpsGreedy[0][0][:,2])
    axs[1].plot(EpsGreedy[1][0][:,2])
    axs[1].plot(EpsGreedy[2][0][:,2])
    axs[1].set_title("Gini Index of Epsilon Greedy Algorithm")

    axs[2].plot(EpsGreedy[0][0][:,3])
    axs[2].plot(EpsGreedy[1][0][:,3])
    axs[2].plot(EpsGreedy[2][0][:,3])
    axs[2].set_title("PSP Score of Epsilon Greedy Algorithm")

# %%
with open ('./Outputs/FairEpsGreedy', 'rb') as fp:
    FairEpsGreedy = pickle.load(fp)
    fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

    axs[0].plot(np.cumsum(FairEpsGreedy[0][0][:,1]))
    axs[0].plot(np.cumsum(FairEpsGreedy[1][0][:,1]))
    axs[0].plot(np.cumsum(FairEpsGreedy[2][0][:,1]))
    axs[0].set_title("Accuracy of Fair UCB Algorithm")

    axs[1].plot(FairEpsGreedy[0][0][:,2])
    axs[1].plot(FairEpsGreedy[1][0][:,2])
    axs[1].plot(FairEpsGreedy[2][0][:,2])
    axs[1].set_title("Gini Index of Fair UCB Algorithm")

    axs[2].plot(FairEpsGreedy[0][0][:,3])
    axs[2].plot(FairEpsGreedy[1][0][:,3])
    axs[2].plot(FairEpsGreedy[2][0][:,3])
    axs[2].set_title("PSP Score of Fair UCB Algorithm")

# %%
with open ('./Outputs/FairUCB', 'rb') as fp:
    FairUCB = pickle.load(fp)
    fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

    axs[0].plot(np.cumsum(FairUCB[0][0][:,1]))
    axs[0].plot(np.cumsum(FairUCB[1][0][:,1]))
    axs[0].plot(np.cumsum(FairUCB[2][0][:,1]))
    axs[0].set_title("Accuracy of Fair UCB Algorithm")

    axs[1].plot(FairUCB[0][0][:,2])
    axs[1].plot(FairUCB[1][0][:,2])
    axs[1].plot(FairUCB[2][0][:,2])
    axs[1].set_title("Gini Index of Fair UCB Algorithm")

    axs[2].plot(FairUCB[0][0][:,3])
    axs[2].plot(FairUCB[1][0][:,3])
    axs[2].plot(FairUCB[2][0][:,3])
    axs[2].set_title("PSP Score of Fair UCB Algorithm")

# %%
with open ('./Outputs/UCB', 'rb') as fp:
    UCB = pickle.load(fp)
    fig, axs = plt.subplots(3,1, sharex=True, figsize=(20,20))

    axs[0].plot(np.cumsum(UCB[0][0][:,1]))
    axs[0].plot(np.cumsum(UCB[1][0][:,1]))
    axs[0].plot(np.cumsum(UCB[2][0][:,1]))
    axs[0].set_title("Accuracy of UCB Algorithm")

    axs[1].plot(UCB[0][0][:,2])
    axs[1].plot(UCB[1][0][:,2])
    axs[1].plot(UCB[2][0][:,2])
    axs[1].set_title("Gini Index of UCB Algorithm")

    axs[2].plot(UCB[0][0][:,3])
    axs[2].plot(UCB[1][0][:,3])
    axs[2].plot(UCB[2][0][:,3])
    axs[2].set_title("PSP Score of UCB Algorithm")

# %%
UCB
# Out:
# [(array([[ 6.        ,  1.        ,  0.0500019 , -0.33333333],
#          [19.        ,  0.        ,  0.1000009 , -0.5       ],
#          [ 5.        ,  1.        ,  0.15000057, -0.6       ],
#          ...,
#          [ 0.        ,  1.        ,  0.05173984, -0.99961098],
#          [ 0.        ,  1.        ,  0.05173983, -0.99961099],
#          [ 0.        ,  1.        ,  0.05173982, -0.99961099]]),
#   array([1.94661e+05, 1.70000e+01, 1.10000e+01, 1.59000e+02, 1.70000e+01,
#          4.70000e+01, 1.48000e+02, 4.20000e+01, 5.30000e+01, 8.10000e+01,
#          1.70000e+01, 1.20000e+01, 2.90000e+01, 1.20000e+01, 9.00000e+00,
#          1.80000e+01, 9.00000e+00, 9.00000e+00, 7.00000e+00, 7.00000e+00]),
#   array([    38, 195329], dtype=int64)),
#  (array([[10.        ,  0.        ,  0.0500019 , -0.33333333],
#          [ 5.        ,  1.        ,  0.1000009 , -0.5       ],
#          [ 6.        ,  0.        ,  0.15000057, -0.6       ],
#          ...,
# ...

# %% [markdown]
# 3Metrics * 3Rewards * 3Arms * 3Algorithms
# 3 Algorithms * 3x3 3 metrics on y axis, 3 arms on x axis, 3 rewards in plot
# 3 metrics on y axis, 3 rewards in plot, 3 arms in plot

# %%
fig, axs = plt.subplots(3,3, sharex=True, figsize=(20,20))

axs[0,0].plot(np.cumsum(EpsGreedy[0][0][:,1]))
axs[0,0].plot(np.cumsum(EpsGreedy[1][0][:,1]))
axs[0,0].plot(np.cumsum(EpsGreedy[2][0][:,1]))
axs[0,0].set_title("Accuracy of Epsilon Greedy Algorithm")

axs[1,0].plot(EpsGreedy[0][0][:,2])
axs[1,0].plot(EpsGreedy[1][0][:,2])
axs[1,0].plot(EpsGreedy[2][0][:,2])
axs[1,0].set_title("Gini Index of Epsilon Greedy Algorithm")

axs[2,0].plot(EpsGreedy[0][0][:,3])
axs[2,0].plot(EpsGreedy[1][0][:,3])
axs[2,0].plot(EpsGreedy[2][0][:,3])
axs[2,0].set_title("PSP Score of Epsilon Greedy Algorithm")

axs[0,1].plot(np.cumsum(FairEpsGreedy[0][0][:,1]))
axs[0,1].plot(np.cumsum(FairEpsGreedy[1][0][:,1]))
axs[0,1].plot(np.cumsum(FairEpsGreedy[2][0][:,1]))
axs[0,1].set_title("Accuracy of Fair Epsilon Greedy Algorithm")

axs[1,1].plot(FairEpsGreedy[0][0][:,2])
axs[1,1].plot(FairEpsGreedy[1][0][:,2])
axs[1,1].plot(FairEpsGreedy[2][0][:,2])
axs[1,1].set_title("Gini Index of Fair Epsilon Greedy Algorithm")

axs[2,1].plot(FairEpsGreedy[0][0][:,3])
axs[2,1].plot(FairEpsGreedy[1][0][:,3])
axs[2,1].plot(FairEpsGreedy[2][0][:,3])
axs[2,1].set_title("PSP Score of Fair Epsilon Greedy Algorithm")

axs[0,2].plot(np.cumsum(BalancedEpsGreedy[0][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedEpsGreedy[1][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedEpsGreedy[2][0][:,1]))
axs[0,2].set_title("Accuracy of Balanced Epsilon Greedy Algorithm")

axs[1,2].plot(BalancedEpsGreedy[0][0][:,2])
axs[1,2].plot(BalancedEpsGreedy[1][0][:,2])
axs[1,2].plot(BalancedEpsGreedy[2][0][:,2])
axs[1,2].set_title("Gini Index of Balanced Epsilon Greedy Algorithm")

axs[2,2].plot(BalancedEpsGreedy[0][0][:,3])
axs[2,2].plot(BalancedEpsGreedy[1][0][:,3])
axs[2,2].plot(BalancedEpsGreedy[2][0][:,3])
axs[2,2].set_title("PSP Score of Balanced Epsilon Greedy Algorithm")
# Out:
# Text(0.5, 1.0, 'PSP Score of Balanced Epsilon Greedy Algorithm')

# %%
with open ('./Outputs/LinUCB', 'rb') as fp:
    LinUCB = pickle.load(fp)
with open ('./Outputs/FairLinUCB', 'rb') as fp:
    FairLinUCB = pickle.load(fp)
    
with open ('./Outputs/BalancedLinUCB', 'rb') as fp:
    BalancedLinUCB = pickle.load(fp)

# %%
fig, axs = plt.subplots(3,3, figsize=(20,20))

axs[0,0].plot(np.cumsum(LinUCB[0][0][:,1]))
axs[0,0].plot(np.cumsum(LinUCB[1][0][:,1]))
axs[0,0].plot(np.cumsum(LinUCB[2][0][:,1]))
axs[0,0].set_title("Accuracy of LinUCB Algorithm")

axs[1,0].plot(LinUCB[0][0][:,2])
axs[1,0].plot(LinUCB[1][0][:,2])
axs[1,0].plot(LinUCB[2][0][:,2])
axs[1,0].set_title("Gini Index of LinUCB Algorithm")

axs[2,0].plot(LinUCB[0][0][:,3])
axs[2,0].plot(LinUCB[1][0][:,3])
axs[2,0].plot(LinUCB[2][0][:,3])
axs[2,0].set_title("PSP Score of LinUCB Algorithm")

axs[0,1].plot(np.cumsum(FairLinUCB[0][0][:,1]))
axs[0,1].plot(np.cumsum(FairLinUCB[1][0][:,1]))
axs[0,1].plot(np.cumsum(FairLinUCB[2][0][:,1]))
axs[0,1].set_title("Accuracy of Fair LinUCB Algorithm")

axs[1,1].plot(FairLinUCB[0][0][:,2])
axs[1,1].plot(FairLinUCB[1][0][:,2])
axs[1,1].plot(FairLinUCB[2][0][:,2])
axs[1,1].set_title("Gini Index of Fair LinUCB Algorithm")

axs[2,1].plot(FairLinUCB[0][0][:,3])
axs[2,1].plot(FairLinUCB[1][0][:,3])
axs[2,1].plot(FairLinUCB[2][0][:,3])
axs[2,1].set_title("PSP Score of Fair LinUCB Algorithm")

axs[0,2].plot(np.cumsum(BalancedLinUCB[0][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedLinUCB[1][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedLinUCB[2][0][:,1]))
axs[0,2].set_title("Accuracy of Balanced LinUCB Algorithm")

axs[1,2].plot(BalancedLinUCB[0][0][:,2])
axs[1,2].plot(BalancedLinUCB[1][0][:,2])
axs[1,2].plot(BalancedLinUCB[2][0][:,2])
axs[1,2].set_title("Gini Index of Balanced LinUCB Algorithm")

axs[2,2].plot(BalancedLinUCB[0][0][:,3])
axs[2,2].plot(BalancedLinUCB[1][0][:,3])
axs[2,2].plot(BalancedLinUCB[2][0][:,3])
axs[2,2].set_title("PSP Score of Balanced LinUCB Algorithm")
# Out:
# Text(0.5, 1.0, 'PSP Score of Balanced LinUCB Algorithm')

# %%
fig, axs = plt.subplots(3,3, sharex=True, figsize=(20,20))

axs[0,0].plot(np.cumsum(UCB[0][0][:,1]))
axs[0,0].plot(np.cumsum(UCB[1][0][:,1]))
axs[0,0].plot(np.cumsum(UCB[2][0][:,1]))
axs[0,0].set_title("Accuracy of UCB Algorithm")

axs[1,0].plot(UCB[0][0][:,2])
axs[1,0].plot(UCB[1][0][:,2])
axs[1,0].plot(UCB[2][0][:,2])
axs[1,0].set_title("Gini Index of UCB Algorithm")

axs[2,0].plot(UCB[0][0][:,3])
axs[2,0].plot(UCB[1][0][:,3])
axs[2,0].plot(UCB[2][0][:,3])
axs[2,0].set_title("PSP Score of UCB Algorithm")

axs[0,1].plot(np.cumsum(FairUCB[0][0][:,1]))
axs[0,1].plot(np.cumsum(FairUCB[1][0][:,1]))
axs[0,1].plot(np.cumsum(FairUCB[2][0][:,1]))
axs[0,1].set_title("Accuracy of Fair UCB Algorithm")

axs[1,1].plot(FairUCB[0][0][:,2])
axs[1,1].plot(FairUCB[1][0][:,2])
axs[1,1].plot(FairUCB[2][0][:,2])
axs[1,1].set_title("Gini Index of Fair UCB Algorithm")

axs[2,1].plot(FairUCB[0][0][:,3])
axs[2,1].plot(FairUCB[1][0][:,3])
axs[2,1].plot(FairUCB[2][0][:,3])
axs[2,1].set_title("PSP Score of Fair UCB Algorithm")

axs[0,2].plot(np.cumsum(BalancedUCB[0][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedUCB[1][0][:,1]))
axs[0,2].plot(np.cumsum(BalancedUCB[2][0][:,1]))
axs[0,2].set_title("Accuracy of Balanced UCB Algorithm")

axs[1,2].plot(BalancedUCB[0][0][:,2])
axs[1,2].plot(BalancedUCB[1][0][:,2])
axs[1,2].plot(BalancedUCB[2][0][:,2])
axs[1,2].set_title("Gini Index of Balanced UCB Algorithm")

axs[2,2].plot(BalancedUCB[0][0][:,3])
axs[2,2].plot(BalancedUCB[1][0][:,3])
axs[2,2].plot(BalancedUCB[2][0][:,3])
axs[2,2].set_title("PSP Score of Balanced UCB Algorithm")
# Out:
# Text(0.5, 1.0, 'PSP Score of Balanced UCB Algorithm')
